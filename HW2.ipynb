# %% [markdown]
# CSc 599.69 Visualization, Spring 2017, Homework 2
# =======================================================
#
#
# Let me be very clear. Regardless of how little time or what happened in your life, your solutions should
# not contain code or text that were copied from other students (this year or prior years). Doing so
# is a violation of the academic honor code. Please
#
#
# Exercise 1: Advanced matplotlib: Publication-ready plots
# ----------------------------------------------------------------------------------
# The goal of this exercise is to get accustomed to object-oriented interface to matplotlib and go through entire process of figure preparation - from design to the final figure ready for submission. Exercise taken from https://github.com/btel/visualization-talk updated by Hannah Aizenman and Michael Grossberg
#
# * Given the code below:
#     * Read comments and identify basic matplotlib artists (like lines, axes, etc.)
#     * Try to understand how ``spines`` in matplotlib work and how they provide framing and at the same time show data range and hide the default top ticks.

# %%
# %matplotlib inline
import numpy as np
import matplotlib


import matplotlib.pyplot as plt
import matplotlib as mpl

# generate some random data
t = np.arange(0.1, 9.2, 0.15)
y = t+np.random.rand(len(t))

#first create the figure
fig = plt.figure(figsize=(8,6))

#create a grid of 1 row and 1 column for the plot
#[left, bottom, width, height]
gs = mpl.gridspec.GridSpec(1,1)
#put a plot in the first row, first column
ax = fig.add_subplot(gs[0])

ax.plot(t,y, marker='.', color='k', linestyle='',
        markersize=4, clip_on=False)

#set axis limits 
ax.set_xlim((-2,12))
ax.set_ylim((-2,12))

#scale the view to show all datapoints
ax.autoscale_view()

#set labels
ax.set_xlabel(r'voltage (V, $\mu$V)', fontsize=12, family='sans-serif')
ax.set_ylabel('luminescence (L)', fontsize=12, family='sans-serif')

fig.savefig('mpl_template.svg')

# %% [markdown]
# * Import the supplied CSV file ``crabs.csv``. The easiest way to do it is to use ``numpy.recfromcsv`` function. This returns a NumPy record array with the fields as descibed in Pt. 2 of Advanded matplotlib exercise.

# %%
data = np.recfromcsv('crabs.csv')
data.dtype.fields
print(type(data))
# Out:
# <class 'numpy.recarray'>

# %% [markdown]
# These data have 0 rows and 8 columns, describing 5 morphological measurements on 50 crabs each of two colour forms and both sexes, of the species Leptograpsus variegatus collected at Fremantle, W. Australia (From Venables & Ripley,Modern Applied Statistics with S, Springer, 2002).
#
# The file contain following columns:
#     * ``sp`` species - B (blue) or O (orange)
#     * ``sex`` you may guess
#     * ``index`` 1:50 for each group (blue male, blue female, etc.)
#     * ``FL`` frontal lobe size (mm)
#     * ``RW`` rear width (mm).
#     * ``CL`` carapace length (mm).
#     * ``CW`` carapace width (mm).
#     * ``BD`` body depth (mm).
#
# Recommend way of doing it is with ``numpy.recfromcsv`` function (returns a numpy record array introduced during the numpy lecture), but other alternatives are allowed (such as ``csv`` module, pandas, or standard IO).
#
# 3. Modify the plot template to plot two of the above measurements against each other. Do not forget to update labels!
#
# 4. Add a third dimension to the plot using different methods (choose two):
#
#     * plot two different dependent (y) variable against the same independent (x) variable using different markers. Use double y-axes to show the data dimensions (you may define a new Axes object of type ``matplotlib.axes.Axes.twinx``).
#
#     * represent the third variable with the circles of different sizes (Hint: use ``markersize`` keyword argument of ``plot``)
#
#     * represent the third variable on a color scale, add a color bar to the plot
#     * represent the data as a short line segments, where the position of line on XY plane encodes two of the variables and the angle of the segment encodes the third one.
#
#     Which of the data representation is the most accurate?
#
# 5. Group variables belonging to the same crab group (blue male, blue female, etc., choose one method):
#     * by connecting the points with a line
#     * by use of color (make sure not to use colors both for representing groups and representing one of dependent variables)
#
# 6. Repeat exercise 4 and 5, but represent different dependent variables/groups in different (non-overlapping) axes.
#     Does use of multiple panels increase readability?
#
# 7. Preparing publication-quality figure file. Let us assume that you want to prepare the final figure for submission by combining panels each of which contains one of the figures presented above. Although it is possible (and straigthforward) to do that by creating independent axes in the figure, often such approach pose several problems (for example, if the panel itself contains several axes, we would have to shift all of them to new positions). Therefore, here we will do that as a post processing step:
#
#    * choose two of above figures and export them to SVG file.
#
#    * modify the ``combine_svg.py`` example to read in the figures and
#      move them to their final positions.
#
#    * use inkscape from command line to export the generated SVG file
#      to a format of choice, such as PDF::
#
#          inkscape final_figure1.svg --export-pdf=final_figure1.pdf
#
#    * (Optional) You may easily automate the entire process using a
#      simple ``Makefile`` similar to this one:
#
#          mpl_figure1.svg : mpl_figure1.py
#              python mpl_figure1.py mpl_figure1.svg
#
#          mpl_figure2.svg : mpl_figure2.py
#              python mpl_figure2.py mpl_figure2.svg
#
#          final_figure1.svg : final_figure1.py mpl_figure1.svg mpl_figure2.svg
#              python combine_svg.py
#
#          %.pdf : %.svg
#              inkscape $< --export-pdf=$@
#
# 8. "Test drive" your figure. Use the "Visualization Checklist" from https://github.com/btel/visualization-talk/blob/master/Lecture/checklist/checklist.rst What could be improved?

# %% [markdown]
# # #1

# %%
##ANSWERS
#1#
import pandas
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl


data = np.recfromcsv('crabs.csv')

cw=data['cw']
bd=data['bd']

plt.title('Crabs: CW vs BW',fontsize=20) 
plt.ylabel('CW',fontsize=20) 
plt.xlabel('BD',fontsize=20)
plt.plot(cw,bd,marker='.', color='k', linestyle='',markersize=4, clip_on=False)
plt.rcParams['figure.figsize'] = (12.0,10.0) 
plt.rcParams.update({'font.size': 12})
plt.show()

# %%
#1.1
import pandas
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl


data = np.recfromcsv('crabs.csv')

cw=data['cw']
bd=data['bd']
#added
rw=data['rw']


plt.title('Crabs: BW vs CW&RW',fontsize=20) 
plt.ylabel('CW',fontsize=20) 
plt.xlabel('BD',fontsize=20)
plt.ylim((5,23))
plt.xlim((0,65))

plt.plot(cw,bd,marker='.',label='CW', color='k', linestyle='',markersize=4, clip_on=False)
plt.twinx()
plt.ylabel('RW',fontsize=20)
plt.ylim((5,23))
plt.plot(cw,rw,marker='o',label='RW', color='r', linestyle='',markersize=4, clip_on=False)


plt.rcParams['figure.figsize'] = (12.0,10.0) 
plt.rcParams.update({'font.size': 12})
plt.legend()
plt.show()

# %% [markdown]
# # #2

# %%
#1.2 - b

import pandas
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

data = np.recfromcsv('crabs.csv')

cw=data['cw']
bd=data['bd']
rw=data['rw']

plt.title('Crabs: CW vs BD&RW',fontsize=20) 
plt.xlabel('CW',fontsize=20) 
plt.ylabel('BD',fontsize=20)
plt.plot(cw,bd,marker='.', color='k', linestyle='',markersize=4, clip_on=False)

cm = plt.cm.get_cmap('RdYlBu')
sc = plt.scatter(cw, rw, c=bd, vmin=0, vmax=20, s=20, cmap=cm)
cbar = plt.colorbar(sc)
cbar.set_label("RW",fontsize=20)

plt.ylim((5,23))
plt.xlim((0,65))

plt.rcParams['figure.figsize'] = (12.0,10.0) 
plt.savefig('part2.svg')
plt.show()

# %% [markdown]
# # #3

# %%
#1.3 - b

cw=data['cw']
bd=data['bd']
sex=data['sex']
#print(type(sex))
#print(type(cw))

cw_F=[]
cw_M=[]

for i,value in enumerate(cw):
    if (sex[i]==b'M'):
        #print(value)
        cw_M.append(value)
    else:
        cw_F.append(value)

bd_F=[]
bd_M=[]

for i,value in enumerate(bd):
    if (sex[i]==b'M'):
        #print(value)
        bd_M.append(value)
    else:
        bd_F.append(value)

plt.title('Crabs: CW vs BD (Male / Female)',fontsize=20) 
plt.ylabel('BD',fontsize=20) 
plt.xlabel('CW',fontsize=20)

plt.plot(cw_M,bd_M,marker='o', color='blue', linestyle='',markersize=4,label='Male', clip_on=False)
plt.plot(cw_F,bd_F,marker='o', color='red', linestyle='',markersize=4,label='Female', clip_on=False)


plt.ylim((5,23))
plt.xlim((0,65))

plt.rcParams.update({'font.size': 20})
plt.rcParams['figure.figsize'] = (12.0,10.0) 
plt.legend()
plt.show()

plt.savefig('part3.svg')

# %%
#1.3 - b

cw=data['cw']
sp=data['sp']
rw=data['rw']
sex=data['sex']
#print(type(sex))
#print(type(cw))

cw_BF=[]
cw_BM=[]
rw_BF=[]
rw_BM=[]

for i,value in enumerate(cw):
    if (sp[i]==b'B'):
        if (sex[i] == b'F'):
        #print(value)
            cw_BF.append(value)
        else:
            cw_BM.append(value)
        
for i,value in enumerate(rw):
    if (sp[i]==b'B'):
        if (sex[i] == b'F'):
        #print(value)
            rw_BF.append(value)
        else:
            rw_BM.append(value)

        
cw_OF=[]
cw_OM=[]
rw_OF=[]
rw_OM=[]
        
for i,value in enumerate(cw):
    if (sp[i]==b'O'):
        if (sex[i]==b'F'):
        #print(value)
            cw_OF.append(value)
        else:
            cw_OM.append(value)
        
for i,value in enumerate(rw):
    if (sp[i]==b'O'):
        if (sex[i]==b'F'):
        #print(value)
            rw_OF.append(value)
        else:
            rw_OM.append(value)

        
fig = plt.figure(figsize=(12,10)) 
grid = mpl.gridspec.GridSpec(1,2)
ax = fig.add_subplot(grid[0])
ax2 = fig.add_subplot(grid[1])

ax.plot(cw_BM,rw_BM, marker='.', color='blue', linestyle='',markersize=4, label='Blue Male', clip_on=False)
ax.plot(cw_BM,rw_BF, marker='o', color='red', linestyle='',markersize=4,label='Blue Female', clip_on=False)
ax.set_ylabel('RW',fontsize=20)
ax.set_xlabel('CW',fontsize=20)
ax.set_xlim((15,60))
ax.set_ylim((6,21))

ax2.plot(cw_OM,rw_OM, marker='.', color='black', linestyle='',markersize=4, label='Orange Male', clip_on=False)
ax2.plot(cw_OM,rw_OF, marker='+', color='green', linestyle='',markersize=4,label='Orange Female', clip_on=False)
ax2.set_ylabel('RW',fontsize=20)
ax2.set_xlabel('CW',fontsize=20)
ax2.set_xlim((15,60))
ax2.set_ylim((6,21))

ax.legend(bbox_to_anchor=(0.8, 0.94), loc=7)
ax2.legend(bbox_to_anchor=(1.2, 0.94), loc=7, borderaxespad=5.)

plt.savefig('part4.svg')
plt.show()

# %% [markdown]
# Exercise 2: Working with Image Data
# ----------------------------------------------------------------------------------
# The goal of this exercise is become familiar with using numpy and matplotlib image manipulation and graphing.
#
# * You will need to separately download the file AQUA.2013089.2055.mat This file is a matlab file. It is basically a multispectral image that was originally obtained from NASA http://rapidfire.sci.gsfc.nasa.gov/realtime/. The file I am giving you is a "real" data file ... it is big 51MB!
#
# **Please don't check this into any repo.**
#
# **Please don't check this into any repo.**
#
# **Please don't check this into any repo.**
#
# http://glasslab.engr.ccny.cuny.edu/u/grossberg/data/AQUA.2013089.2055.mat
#
# NASA publishes satillite images in hdf and netcdf formats (mostly). Unfortunately, often this formats need additional libraries to be read easily so we have reformatted this to a matlab format which is easy to read.
#
#     from scipy.io import loadmat
#
# imports a function that can read the files.

# %%
from matplotlib import pyplot as plt
from scipy.io import loadmat
data = loadmat('AQUA.2013089.2055.mat')

# %% [markdown]
# If you are curious what images are in the file you can check the keys you can do the following:

# %%
print(data.keys())
# Out:
# dict_keys(['__header__', '__version__', 'ICE', 'B3', 'B4', 'B7', '__globals__', 'B1', 'RGB', 'B5', 'B6', 'B2'])

# %% [markdown]
# The 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7' are image bands. The represent different spectra of light similar to the way a pocket camera takes a red grean and blue image to make a color image. The "RGB" is a color image of this scene. This particular image is of clouds over sea ice and snow so you don't see much in the color image. First lets just look at a band. To access data from a band, note that the data is just a dictionary of numpy arrays. So data['B1'] is just an array containing the first band. Lets check how big it is (all the bands are the same size).

# %%
data['B1'].shape
# Out:
# (914, 667)

# %% [markdown]
# Lets check some basic statistics of this array:

# %%
print('max:',data['B1'].max())
print('min:',data['B1'].min())
print('mean:',data['B1'].mean())
# Out:
# max: 1.03584373503
# min: 0.385050565202
# mean: 0.732060335914

# %% [markdown]
# That's way too many decimal places ...

# %%
print('max:',round(data['B1'].max(),2))
print('min:',round(data['B1'].min(),2))
print('mean:',round(data['B1'].mean(),2))
# Out:
# max: 1.04
# min: 0.39
# mean: 0.73

# %% [markdown]
# This numbers are unitless because they represent reflectance (albedo). If a unit of light shines on the surface the reflectance is the number between 0 and 1 representing the fraction of light reflected. 0 is black. 1 is white (for that band ... which may be green light). Lets see what the image looks like.

# %%
from matplotlib import pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.imshow(data['B1'])
plt.show()

# %% [markdown]
# This is horrible for oh, so many reasons. One is the everpresent use of the jet color map. Lets pick a better color map.

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
cmap = plt.get_cmap('hot')
ax.imshow(data['B1'], cmap = cmap)
plt.show()

# %% [markdown]
# We need a colorbar to interpret the colors. We can add one:

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
cmap = plt.get_cmap('hot')
fig_image = ax.imshow(data['B1'], cmap = cmap)
cax = fig.colorbar(fig_image, ax = ax)
cax.set_label("Reflectance")
plt.show()

# %% [markdown]
# One problem we will find with a color map is that there are too many gradiations so it is hard to read reflectance (quantitative ratio variable) with more than 10 steps. However because this is really an image, if we introduced quantization they might be confused with edges on the ground. We will save this discussion for a future homework. Right now lets look in more detail at the kind of values we have beyond the max and min. We need the histogram.

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
fig_image = ax.hist(data['B1'],facecolor='black')
plt.show()

# %% [markdown]
# The missing gaps in the data may be a confict of quantization. We can now look at another band. Lets look at Band 6:

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
cmap = plt.get_cmap('hot')
fig_image = ax.imshow(data['B6'], cmap = cmap)
cax = fig.colorbar(fig_image)
cax.set_label("Reflectance")
plt.show()

# %% [markdown]
# Looks somewhat different. One way to compare the bands would be to do a scatter plot of the values of Band 1 vs Band 6. The problem is that there are too many pixels.
#
# 1. Find the total number of pixels in the image using data['B1'].shape, call that **number** N
# 2. We will set a sample percentage which we call spercentage as .45%  This should be around 4K points.
# 3. Number of samples we will use will be N*spercentage which should be around 4K points
# 4. To randomly choose points here is a snipit of code to get random indices:
#
#         samplesInds =range(1,N)
#         np.random.shuffle(samplesInds)
#         samplesInds = samplesInds[0:numSamps]
#
# 5. Lets call the image b1=data['B1']. Then b1.ravel()[sampleInds] are the values at the sampled pixels. Make a scatter plot of sampled b1 (x-axis) vs b6 (y-axis) where b6 are the corresponding points from Band 6, 'B6'.
# 6. Title the image "A comparison of Band 1 and Band 6 Reflectance."
# 7. Title the x-axis Band 1 Reflectance and y Band 6 Reflectance
# 8. All the dots at this point may look like a big jumble. Set the alpha (transparency) low enough so you can see where the dots are bunching up.
# 9. Chose an size (other than default), color, and marker.
#
# One thing we like to do is compare with a linear regression. If the data fits a line then there should be a good corrolation between line fit and the data.
#
# 10. Use the polyfit function to fit the B1 samples vs. the B6 samples to get a line fit.
# 11. Use polyval (on two x values ... one just below the min (90%) and one just above max (110%)) to get a bet fit line.
# 12. Show the line (plot) in red on top of the samples.
# 13. Make sure you have a legend that says "Linear regression line"
# 14. Compute the slope and use matplotlibs "text" function to put a label "slope = " (the slope value) on the graph. You will need to manually adjust the position so it doesn't block other elements.
# 15. From scipy stats use get the pearson corrlollation coefficient and use the text to put that on the graph.
# 16. Do the same for Band 7 vs Band 6. Which is more related?

# %% [markdown]
# # Exercise 2: Answers
# # #1-#4

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import scipy.stats

pixels = data['B1'].shape
#print(pixels)
N = pixels[0]*pixels[1]
print('Number of pixels N:',N)

spercentage = 0.45
numSamps = round(N*spercentage)
print('Sample of 45%: ' + str(numSamps))

samplesInds = list(range(1,N))
np.random.shuffle(samplesInds)
samplesInds = samplesInds[0:numSamps]
# Out:
# Number of pixels N: 609638
# Sample of 45%: 274337

# %% [markdown]
# # #5-#9

# %%
b1 = data['B1']
b1_ = b1.ravel()[samplesInds]

b6 = data['B6']
b6_ = b6.ravel()[samplesInds]


fig = plt.figure(figsize=(12.0,12.0))
grid = mpl.gridspec.GridSpec(1,1)
ax = fig.add_subplot(grid[0])

ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_linewidth(0.5)
ax.xaxis.set_ticks_position('bottom')

ax.spines['right'].set_visible(False)
ax.spines['left'].set_linewidth(0.5)
ax.yaxis.set_ticks_position('left')

ax.xaxis.set_tick_params('major', length=2, labelsize=20)
ax.yaxis.set_tick_params('major', length=2, labelsize=20)

ax.set_xlim((0.4,1.1))
ax.set_ylim((0,0.75))

ax.plot(b1_,b6_, marker='.', color='black', linestyle='',markersize=2, alpha=.1 ,clip_on=False)
ax.autoscale_view()

plt.title("Band 1 vs. Band 6 Reflectance",fontsize=20)
ax.set_xlabel('Band 1 Reflectance', fontsize=20)
ax.set_ylabel('Band 6 Reflectance', fontsize=20)

linePoly = np.polyfit(b1_,b6_,1)
y1 = np.polyval(linePoly,1.1) 
y2 = np.polyval(linePoly,0.90)


plt.plot(b1_,np.polyval(linePoly,b1_),'-',label='Linear Regression')
plt.legend(bbox_to_anchor=(1, 1), loc=9, borderaxespad=5.,fontsize=20)

slope = ('Slope = ' + str(linePoly[0]))
coeff = ('\n Pearson Coeficient:' + str(scipy.stats.pearsonr(b1_,b6_)))
ax.text(1.23, .65, slope + coeff, verticalalignment='bottom', horizontalalignment='right', fontsize=20)
plt.show()

# %%
b7 = data['B7']
b7_ = b7.ravel()[samplesInds]

b6 = data['B6']
b6_ = b6.ravel()[samplesInds]


fig = plt.figure(figsize=(12.0,12.0))
grid = mpl.gridspec.GridSpec(1,1)
ax = fig.add_subplot(grid[0])

ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_linewidth(0.5)
ax.xaxis.set_ticks_position('bottom')

ax.spines['right'].set_visible(False)
ax.spines['left'].set_linewidth(0.5)
ax.yaxis.set_ticks_position('left')

ax.xaxis.set_tick_params('major', length=2, labelsize=20)
ax.yaxis.set_tick_params('major', length=2, labelsize=20)

ax.set_xlim((0,0.5))
ax.set_ylim((0,0.6))

ax.plot(b1_,b6_, marker='.', color='black', linestyle='',markersize=2, alpha=.1 ,clip_on=False)
ax.autoscale_view()

plt.title("Band 7 vs. Band 6 Reflectance",fontsize=20)
ax.set_xlabel('Band 7 Reflectance', fontsize=20)
ax.set_ylabel('Band 6 Reflectance', fontsize=20)

linePoly = np.polyfit(b7_,b6_,1)
y1 = np.polyval(linePoly,1.1) 
y2 = np.polyval(linePoly,0.90)


plt.plot(b7_,np.polyval(linePoly,b7_),'-',label='Linear Regression')
plt.legend(bbox_to_anchor=(1, 1), loc=9, borderaxespad=5.,fontsize=20)

slope = ('Slope = ' + str(linePoly[0]))
coeff = ('\n Pearson Coeficient:' + str(scipy.stats.pearsonr(b7_,b6_)))
ax.text(0.77, .65, slope + coeff, verticalalignment='bottom', horizontalalignment='right', fontsize=20)
plt.show()

# %% [markdown]
# Exercise 3: Distributions
# ----------------------------------------------------------------------------------
#
# Download Hannah's world city temperature data from:
#
#      http://glasslab.engr.ccny.cuny.edu/u/hannah/cs217/
#
# For each city there are around 80,000 measurements of temperature from 1980 to 2009 for every 6 hours (4/day).
#
#
# Part A: Box and Whiskers
# *************************************
#
# 1. Convert the temperatures to Fahrenheit from Kelvin so they are more easily interpretable to an American audience.
# 2. Make a box and whiskers diagram where the Y axis is labeled by temperature in degrees Fahrenheit and the X axis is labeled by city. Since you don't want the city names to overlap, rotate the text so they run vertically. Use all the temperatures. Write a caption pointing out what interesting things to interpret from the cities.
# 3. In addition to the previous diagram, make a separate diagrams for the first 20,000 measurements and the last 20,000 measurements. Put them in a single figure (two separate subplots). Use the add_sublot for this. Label/title the total graph and subplots clearly. Do you see any trend?
#
#
# Part B: Pandas and Trend Design Problem
# ********************************************
#
#
# We would like to see if there has been any change over time in the temperatures of the city. Fluctuations may make it hard to see differences. For example a small but steady increase in average winter or summer temperatures, may be masked by hourly fluctuations. Working with dates can be rather tricky. Convert the mat data into Pandas data structures:
#
# http://pandas.pydata.org/
#
# Check out the tutorials on Pandas.
#
# 1. Define Winter as December, January and Februrary; Spring as March, April and May; Summer as June, July and August and Fall as September, October and November. Separately for each **year** (1948-2008) and each **city** compute the average temperature for that seasons.
# 2. Design and create a graph(s) that shows the seasonal trends (or lack of trends) over the years from 1948 to 2008 (last year is incomplete).
#
# * Use small multiples with subplot and/or GridSpec to put multiple plots together for comparison
# * Use linear regresion lines and corelation coeefficients to show existance or lack of trends over time
#
# It is up to you how you will group the graphs. You may do it by city or by season but try to show trends or lack of trends in as compact a way as possible (high data to ink ratio) while supporting many visual queries. Visual queiries should include
#
# * Are there different trends for different seasons?
# * How do city compare? Is there more or less of a change for tropical cities then temperate cities?
#
# Be careful not to washout changes by, for example, grouping different cities together when computing changes. Also consider using filled area under the curve rather than a straight line plot (if appropriate). Also consider you scale carefully. Remember that the 0 of temperature is somewhat arbitrary. Often climatolgists will subtract an average over a series to show differences more clearly. When displaying the trend with the total average subtracted we call this the "temperature anomaly" and label as such. In the caption or somewhere else should clearly describe how the data has been processed (which mean is subtracted, what averages are shown).
#
# Note: Your graphs should be understandable to anyone reading them. Look at them carefully assuming the person viewing them did not read this homework assignment.

# %% [markdown]
# # Exercise 3
# # Part A

# %%
#A.1
from scipy.io import loadmat
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

johannessburgK = loadmat('Johannesburg.mat')
parisK = loadmat('Paris.mat')
saopauloK = loadmat('SaoPaulo.mat')
singaporeK = loadmat('Singapore.mat')
sydneyK = loadmat('Sydney.mat')
vancouverK = loadmat('Vancouver.mat')

print(johannessburgK['time'])
#print(type(johannessburgK['temperature']))

johannessburgF = [(x*9/5 - 459.67) for x in johannessburgK['temperature']]    
parisF = [(x*9/5 - 459.67) for x in parisK['temperature']] 
saopauloF = [(x*9/5 - 459.67) for x in saopauloK['temperature']] 
singaporeF = [(x*9/5 - 459.67) for x in singaporeK['temperature']] 
sydneyF = [(x*9/5 - 459.67) for x in sydneyK['temperature']] 
vancouverF = [(x*9/5 - 459.67) for x in vancouverK['temperature']]
# Out:
# ['1948-01-01T00:00:00' '1948-01-01T06:00:00' '1948-01-01T12:00:00' ...,
#  '2009-06-16T06:00:00' '2009-06-16T12:00:00' '2009-06-16T18:00:00']

# %%
#A.2
fig = plt.figure(figsize=(20,20))

grid = mpl.gridspec.GridSpec(1,1)
ax = fig.add_subplot(grid[0])

data1 = [johannessburgF,parisF, saopauloF, sydneyF,vancouverF,singaporeF]
ax.boxplot(data1)

ax.set_xticklabels(['Johannesburg', 'Paris', 'Saopaulo','Sydney','Vancouver','Singapore'],rotation=45,fontsize=20)
ax.set_title("Temperature of worldwide cities from 1980 to 2009", fontsize=20)

ax.set_xlabel('City', fontsize=20)
ax.set_ylabel('Temperature (F)', fontsize=20)
ax.autoscale_view()
plt.show()

# %%
#A.3
fig = plt.figure(figsize=(20,20))

grid = mpl.gridspec.GridSpec(1,2)
ax1 = fig.add_subplot(grid[0])
ax2 = fig.add_subplot(grid[1])

data1 = [johannessburgF[0:20000],parisF[0:20000], saopauloF[0:20000], sydneyF[0:20000],vancouverF[0:20000],singaporeF[0:20000]]
data2 = [johannessburgF[:-20000],parisF[:-20000], saopauloF[:-20000], sydneyF[:-20000],vancouverF[:-20000],singaporeF[:-20000]]

ax1.boxplot(data1)
ax2.boxplot(data2)

ax1.set_xticklabels(['Johannesburg', 'Paris', 'Saopaulo','Sydney','Vancouver','Singapore'],rotation=45,fontsize=20)
ax1.set_title("Temperature of worldwide cities from 1980 to 2009 (first 20000)", fontsize=15)
ax1.set_xlabel('City', fontsize=20)
ax1.set_ylabel('Temperature (F)', fontsize=20)
ax1.autoscale_view()
  
ax2.set_xticklabels(['Johannesburg', 'Paris', 'Saopaulo','Sydney','Vancouver','Singapore'],rotation=45,fontsize=20)
ax2.set_title("Temperature of worldwide cities from 1980 to 2009 (last 20000)", fontsize=15)
ax2.set_xlabel('City', fontsize=20)
ax2.set_ylabel('Temperature (F)', fontsize=20)
ax2.autoscale_view()

plt.show()

# %%
import pandas as pd
from scipy.io import loadmat
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import statistics
from pylab import *

def averageTemp(temp,time,city):
    combined = {'temprature':temp,'time': time}
    df = pd.DataFrame(combined)
    winterAll = []
    springAll = []
    summerAll = []
    fallAll = []
    
    for year in range(1948,2010):
        winter = df.loc[df['time'].isin([str(year)+'-12',str(year)+'-01',str(year)+'-02'])]
        Av_w = pd.DataFrame.mean(winter['temprature'])
        winterAll.append([year,Av_w])
        
        spring = df.loc[df['time'].isin([str(year)+'-03',str(year)+'-04',str(year)+'-05'])]
        Av_sp = pd.DataFrame.mean(spring['temprature'])
        springAll.append([year,Av_sp])
        
        summer = df.loc[df['time'].isin([str(year)+'-06',str(year)+'-07',str(year)+'-08'])]
        Av_su = pd.DataFrame.mean(summer['temprature'])
        summerAll.append([year,Av_su])
        
        fall = df.loc[df['time'].isin([str(year)+'-09',str(year)+'-10',str(year)+'-11'])]
        Av_f = pd.DataFrame.mean(fall['temprature'])
        fallAll.append([year,Av_f])
        
    winterAll = np.asarray(winterAll)
    springAll = np.asarray(springAll)
    summerAll = np.asarray(summerAll)
    fallAll = np.asarray(fallAll)
    
    
    fig = plt.figure(figsize=(20,20))        
    grid = mpl.gridspec.GridSpec(2,2)
    
    ax1 = fig.add_subplot(grid[0,0])
    ax2 = fig.add_subplot(grid[0,1])
    ax3 = fig.add_subplot(grid[1,0])
    ax4 = fig.add_subplot(grid[1,1])

    ax1.set_xlabel('Year', fontsize=18, family='sans-serif')
    ax1.set_ylabel('Temprature (F)', fontsize=18, family='sans-serif')
    ax1.set_title('Winter Temprature Average for ' + str(city), fontsize=18)
    ax2.set_xlabel('Year', fontsize=18, family='sans-serif')
    ax2.set_ylabel('Temprature (F)', fontsize=18, family='sans-serif')
    ax2.set_title('Spring Temprature Average for ' + str(city), fontsize=18)
    ax3.set_xlabel('Year', fontsize=18, family='sans-serif')
    ax3.set_ylabel('Temprature (F)', fontsize=18, family='sans-serif')
    ax3.set_title('Summer Temprature Average for ' + str(city), fontsize=18)
    ax4.set_xlabel('Year', fontsize=18, family='sans-serif')
    ax4.set_ylabel('Temprature (F)', fontsize=18, family='sans-serif')
    ax4.set_title('Fall Temprature Average for ' + str(city), fontsize=18)
    
    m1,b1 = polyfit(winterAll[:,0],winterAll[:,1],1) 
    m2,b2 = polyfit(springAll[:,0],springAll[:,1],1) 
    m3,b3 = polyfit(summerAll[:,0],summerAll[:,1],1) 
    #m4,b4 = polyfit(fallAll[:,0],fallAll[:,1],1) 
            

    
    ax1.plot(winterAll[:,0], winterAll[:,1], winterAll[:,0], m1*winterAll[:,0]+b1, marker='.', color='k', linestyle='',markersize=7, clip_on=False)
    ax2.plot(springAll[:,0],springAll[:,1], springAll[:,0], m2*springAll[:,0]+b2, marker='.', color='r', linestyle='',markersize=7, clip_on=False)
    ax3.plot(summerAll[:,0],summerAll[:,1], summerAll[:,0], m3*summerAll[:,0]+b3, marker='.', color='b', linestyle='',markersize=7, clip_on=False)
    ax4.plot(fallAll[:,0],fallAll[:,1], marker='.', color='c', linestyle='',markersize=7, clip_on=False)
    
    #scale the view to show all datapoints
    ax1.autoscale_view()
    ax2.autoscale_view()
    ax3.autoscale_view()
    #ax4.autoscale_view()
    
    plt.show()
    
    print('Average temp of ' + str(city)+':')
    print('Winter Averages:\n',winterAll,'\nSpring Averages:\n',springAll,'\nSummer Averages:\n',summerAll,'\nFall Averages:\n',fallAll)

# %%
johannessburgK = loadmat('Johannesburg.mat')
parisK = loadmat('Paris.mat')
saopauloK = loadmat('SaoPaulo.mat')
singaporeK = loadmat('Singapore.mat')
sydneyK = loadmat('Sydney.mat')
vancouverK = loadmat('Vancouver.mat')

johannessburgF = [(x*9/5 - 459.67) for x in johannessburgK['temperature']]    
parisF = [(x*9/5 - 459.67) for x in parisK['temperature']] 
saopauloF = [(x*9/5 - 459.67) for x in saopauloK['temperature']] 
singaporeF = [(x*9/5 - 459.67) for x in singaporeK['temperature']] 
sydneyF = [(x*9/5 - 459.67) for x in sydneyK['temperature']] 
vancouverF = [(x*9/5 - 459.67) for x in vancouverK['temperature']] 

johannessburgTime = [x[0:7] for x in johannessburgK['time']]    
parisTime = [x[0:7] for x in johannessburgK['time']] 
saopauloTime = [x[0:7] for x in johannessburgK['time']] 
singaporeTime = [x[0:7] for x in johannessburgK['time']] 
sydneyTime = [x[0:7] for x in johannessburgK['time']] 
vancouverTime = [x[0:7] for x in johannessburgK['time']]

# %%
averageTemp(johannessburgF,johannessburgTime,'Johannessburg')
averageTemp(parisF,parisTime,'Paris')
averageTemp(saopauloF,saopauloTime,'Sao Paulo')
averageTemp(singaporeF,singaporeTime,'Singapore')
averageTemp(sydneyF,sydneyTime,'Sydney')
averageTemp(vancouverF,vancouverTime,'Vancouver')
# Out:
# Average temp of Johannessburg:
# Winter Averages:
#  [[ 1948.            69.07954407]
#  [ 1949.            71.8454895 ]
#  [ 1950.            69.6080246 ]
#  [ 1951.            71.58852386]
#  [ 1952.            72.07717133]
#  [ 1953.            72.60797119]
#  [ 1954.            71.64196777]
#  [ 1955.            68.91895294]
#  [ 1956.            68.81993866]
#  [ 1957.            71.49748993]
#  [ 1958.            70.22497559]
#  [ 1999.            63.2984581 ]
#  [ 2000.            64.01454163]
#  [ 2001.            65.6027832 ]
#  [ 2002.            66.7257843 ]
#  [ 2003.            64.34533691]
#  [ 2004.            62.8693161 ]
#  [ 2005.            65.18224335]
#  [ 2006.            65.05218506]
#  [ 2007.            64.59396362]
#  [ 2008.            64.56507874]
#  [ 2009.            60.33338547]]
# Fall Averages:
#  [[ 1948.            66.77806854]
#  [ 1949.            66.80969238]
#  [ 1950.            67.05795288]
#  [ 1951.            66.37999725]
#  [ 1952.            67.07228851]
#  [ 1953.            69.78614807]
#  [ 1954.            67.52921295]
#  [ 1955.            64.95678711]
#  [ 1956.            66.97488403]
#  [ 1957.            67.21569061]
#  [ 1958.            68.02818298]
#  [ 1959.            67.81256104]
#  [ 1960.            67.67410278]
#  [ 1961.            70.23665619]
#  [ 1962.            66.10160065]
#  [ 1963.            69.83118439]
#  [ 1964.            66.00959778]
#  [ 1965.            68.53800201]
#  [ 1966.            66.91061401]
#  [ 1967.            69.32524872]
#  [ 1968.            67.23947144]
#  [ 1969.            68.75661469]
#  [ 1970.            66.37012482]
#  [ 1971.            65.99725342]
#  [ 1972.            68.39015198]
#  [ 1973.            66.43387604]
#  [ 1974.            66.99713898]
#  [ 1975.            67.56879425]
#  [ 1976.            66.10704803]
#  [ 1977.            68.08506012]
#  [ 1978.            67.55543518]
#  [ 1979.            67.37347412]
#  [ 1980.            66.69599915]
#  [ 1981.            67.51934052]
#  [ 1982.            68.59140778]
#  [ 1983.            67.04512787]
#  [ 1984.            67.71564484]
#  [ 1985.            67.44864655]
#  [ 1986.            67.28102112]
#  [ 1987.            66.94523621]
#  [ 1988.            66.53180695]
#  [ 1989.            65.5690155 ]
#  [ 1990.            67.5272522 ]
#  [ 1991.            66.75431061]
#  [ 1992.            65.99922943]
#  [ 1993.            68.50140381]
#  [ 1994.            68.47373962]
#  [ 1995.            66.63417053]
#  [ 1996.            65.92604065]
#  [ 1997.            69.74262238]
#  [ 1998.            67.24241638]
#  [ 1999.            65.90182495]
#  [ 2000.            68.71456146]
#  [ 2001.            68.03811646]
#  [ 2002.            69.8682251 ]
#  [ 2003.            67.72827911]
#  [ 2004.            69.04091644]
#  [ 2005.            68.30586243]
#  [ 2006.            67.94347382]
#  [ 2007.            69.18663788]
#  [ 2008.            67.38819122]
#  [ 2009.                    nan]]
# Average temp of Singapore:
# Winter Averages:
#  [[ 1948.            75.16933441]
#  [ 1949.            74.63201141]
#  [ 1950.            74.99254608]
#  [ 1951.            74.69553375]
#  [ 1952.            74.74951172]
#  [ 1953.            74.64250946]
#  [ 1954.            75.65748596]
#  [ 1955.            74.59648895]
#  [ 1956.            75.32756805]
#  [ 1957.            75.65951538]
#  [ 1958.            75.61447144]
#  [ 1959.            75.90800476]
#  [ 1960.            75.35723877]
#  [ 1961.            75.37201691]
#  [ 1962.            74.54297638]
#  [ 1963.            74.42154694]
#  [ 1964.            75.82209015]
#  [ 1965.            75.66299438]
#  [ 1966.            76.29850006]
#  [ 1967.            75.75500488]
#  [ 2007.            61.14783096]
#  [ 2008.            61.46915817]
#  [ 2009.                    nan]]
# Average temp of Vancouver:
# Winter Averages:
#  [[ 1948.            21.77854919]
#  [ 1949.            18.39149284]
#  [ 1950.            20.26649094]
#  [ 1951.            21.42648697]
#  [ 1952.            24.87467194]
#  [ 1953.            28.62848282]
#  [ 1954.            25.54599953]
#  [ 1955.            22.5479908 ]
#  [ 1956.            23.16365433]
#  [ 1957.            21.20498657]
#  [ 1958.            31.05348587]
#  [ 1959.            24.95849419]
#  [ 1960.            23.84312248]
#  [ 1961.            27.20549393]
#  [ 1962.            25.65599442]
#  [ 1963.            25.72800636]
#  [ 1964.            23.76153183]
#  [ 1965.            25.14997482]
#  [ 1966.            26.79349136]
#  [ 1967.            25.23399162]
#  [ 1968.            20.57987976]
#  [ 1969.            21.68650055]
#  [ 1970.            25.03947449]
#  [ 1971.            23.61899757]
#  [ 1972.            20.54971886]
#  [ 1973.            23.44198227]
#  [ 1974.            23.19048309]
#  [ 1975.            21.14898872]
#  [ 1976.            26.38339806]
#  [ 1977.            24.56149292]
#  [ 1978.            22.85049438]
#  [ 1979.            21.66599464]
#  [ 1980.            24.00877762]
#  [ 1981.            25.90449524]
#  [ 1982.            22.7385025 ]
#  [ 1983.            23.10749817]
#  [ 1984.            23.35950661]
#  [ 1985.            22.43599129]
#  [ 1986.            26.09192085]
#  [ 1987.            25.89227104]
#  [ 1988.            25.03437805]
#  [ 1989.            22.52748299]
#  [ 1990.            22.53449249]
#  [ 1991.            26.82449341]
#  [ 1992.            26.79138374]
#  [ 1993.            21.93198776]
#  [ 1994.            25.57798195]
#  [ 1995.            26.42098808]
#  [ 1996.            21.85273933]
#  [ 1997.            26.19648743]
#  [ 1998.            26.12849045]
#  [ 1999.            27.72049904]
#  [ 2000.            24.87910461]
#  [ 2001.            25.40999603]
#  [ 2002.            26.84598541]
#  [ 2003.            28.05797005]
#  [ 2004.            27.82735252]
#  [ 2005.            25.6829834 ]
#  [ 2006.            27.2029705 ]
#  [ 2007.            26.23600006]
#  [ 2008.            23.73879433]
#  [ 2009.            26.0256691 ]]
# Spring Averages:
#  [[ 1948.            33.77063751]
#  [ 1949.            38.03000259]
#  [ 1950.            33.10739136]
#  [ 1951.            34.8741188 ]
#  [ 1952.            35.86461258]
#  [ 1953.            35.45666504]
#  [ 1954.            32.25679779]
#  [ 1955.            29.70743942]
#  [ 1956.            37.0546608 ]
#  [ 1957.            38.51227951]
#  [ 1958.            38.98233795]
#  [ 1959.            35.18815994]
#  [ 1960.            34.46226883]
#  [ 1961.            36.19575119]
#  [ 1962.            34.31257248]
#  [ 1963.            36.15416718]
#  [ 1964.            33.41113663]
#  [ 1965.            33.89684677]
#  [ 1966.            35.28888321]
#  [ 1967.            31.98042297]
#  [ 1968.            33.18074799]
#  [ 1969.            36.34052658]
#  [ 1970.            33.23552704]
#  [ 1971.            34.07244873]
#  [ 1972.            35.19498062]
#  [ 1973.            34.18394852]
#  [ 1974.            32.32868576]
#  [ 1975.            31.09215736]
#  [ 1976.            32.16679382]
#  [ 2009.            54.69152069]]
# Fall Averages:
#  [[ 1948.            38.4518013 ]
#  [ 1949.            43.26628876]
#  [ 1950.            39.66186523]
#  [ 1951.            40.86399078]
#  [ 1952.            43.51457214]
#  [ 1953.            43.18370438]
#  [ 1954.            41.60277557]
#  [ 1955.            37.33125687]
#  [ 1956.            39.16192627]
#  [ 1957.            42.22290802]
#  [ 1958.            38.7425766 ]
#  [ 1959.            38.00772476]
#  [ 1960.            39.96548843]
#  [ 1961.            36.94551468]
#  [ 1962.            41.9939537 ]
#  [ 1963.            42.42217255]
#  [ 1964.            38.23817825]
#  [ 1965.            41.27097321]
#  [ 1966.            40.96737289]
#  [ 1967.            40.5381279 ]
#  [ 1968.            37.61065292]
#  [ 1969.            40.09702682]
#  [ 1970.            37.33324051]
#  [ 1971.            37.47615051]
#  [ 1972.            36.64191437]
#  [ 1973.            35.13959122]
#  [ 1974.            38.64416122]
#  [ 1975.            36.80609131]
#  [ 1976.            40.63854218]
#  [ 1977.            35.97334671]
#  [ 1978.            35.28054428]
#  [ 1979.            39.69549561]
#  [ 1980.            38.66444397]
#  [ 1981.            38.07595825]
#  [ 1982.            37.21455765]
#  [ 1983.            36.7116394 ]
#  [ 1984.            35.4783287 ]
#  [ 1985.            30.80774307]
#  [ 1986.            37.66053009]
#  [ 1987.            40.88080978]
#  [ 1988.            39.83985901]
#  [ 1989.            39.57237625]
#  [ 1990.            38.53437805]
#  [ 1991.            38.83306122]
#  [ 1992.            37.08647919]
#  [ 1993.            39.12187576]
#  [ 1994.            38.16596222]
#  [ 1995.            41.29124451]
#  [ 1996.            36.35656738]
#  [ 1997.            40.66915131]
#  [ 1998.            41.81642914]
#  [ 1999.            39.4596138 ]
#  [ 2000.            37.91426849]
#  [ 2001.            39.45911026]
#  [ 2002.            39.54365921]
#  [ 2003.            39.82355118]
#  [ 2004.            40.11484146]
#  [ 2005.            39.34983063]
#  [ 2006.            40.46789551]
#  [ 2007.            38.87558365]
#  [ 2008.            41.72848511]
#  [ 2009.                    nan]]

# %% [markdown]
# Exercise 4: Preparing for Projects
# ----------------------------------------------------------------------------------
#
# I will start a discussion thread for project ideas on blackboard. You should explore the data links given in the syllabus (yes, I know, there are alot).  Consider the following points:
#
# * For your project your visualization should allow for intereactive exploration. It should provide support the Shneiderman Mantra of overview first, then filter and details on demand.
# * Your project should involve data with at least 3 variables, preferably many more. In some cases the complexity may come in the filtering and how that filtering can be rolled up. For example, the temperature data of Ex. 2 has the variables time, city, and temperature. However, we can roll the data up by time of day, by month, by season, by year. We can look at maxes, mins or distributions. You will need to justify whatever exploration you propose.
# * You should consider seeking a domain expert to figure out what kind of queries and exploration you want to support. If you want to work on a scientific visualization of climate data, I could advise you or direct you to a CCNY climate domain expert. If you are interested in (for example), biology data, pyschology data, economic data, or literature/language data you could consult and expert in one of those fields at CCNY. It would be best if you have a project whose use can persist beyond the scope of the course.
#
# At this point you are not yet making a formal project proposal. I just want to see a conversation. Post your suggestion as at least a paragraph pitching your idea. Comment on at least two others on the thread with constructive critism.
